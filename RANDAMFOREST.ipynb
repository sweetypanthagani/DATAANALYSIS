# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import RandomForestClassifier

# %%
df=pd.read_csv('/content/drive/MyDrive/demoDT.csv',sep=",")
print(df)
# Out:
#    State  Literacy   Cleanliness   Crime_Rate  grade
# 0      A        92            90           54      1
# 1      B        56            67           50      0
# 2      C        78            80           62      1
# 3      D        85            75           48      0
# 4      E        60            82           55      0
# 5      F        72            78           60      0
# 6      G        88            85           45      1
# 7      H        64            70           58      0
# 8      I        90            88           42      0
# 9      J        68            72           65      0
# 10     K        75            79           57      1
# 11     L        82            86           49      0
# 12     M        58            65           63      1
# 13     N        77            76           52      0
# 14     O        94            91           40      0
# 15     P        63            74           61      0
# 16     Q        79            83           47      1
# 17     R        71            68           59      1
# 18     S        86            89           43      0
# 19     T        66            71           64      0
# 20     U        81            81           51      1
# 21     V        70            77           56      0
# 22     W        87            84           46      1
# 23     X        62            69           66      1
# 24     Y        76            73           53      0
# 25     Z        83            87           44      1

# %%
feature_cols=['Literacy',' Cleanliness',' Crime_Rate']
feature=df[feature_cols]
Target=df.grade

# %%
RF=RandomForestClassifier(n_estimators=10)
RF.fit(feature,Target)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
l=int(input("enter literacy:"))
cl=int(input("enter cleanlinesss:"))
cr=int(input("enter crimerate:"))
pred=RF.predict([[l,cl,cr]])
if pred==1:
  print("good state")
else:
  print("bad state")
# Out:
# enter literacy:23
# enter cleanlinesss:22
# enter crimerate:11
# bad state
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
import os
output_dir="tree_visualizations"
os.makedirs(output_dir,exist_ok=True)

# %%
RF.estimators_#model name =RF
# Out:
# [DecisionTreeClassifier(max_features='sqrt', random_state=855380389),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1362462866),
#  DecisionTreeClassifier(max_features='sqrt', random_state=460740675),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1227535382),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1595492530),
#  DecisionTreeClassifier(max_features='sqrt', random_state=447661513),
#  DecisionTreeClassifier(max_features='sqrt', random_state=309747379),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1041477907),
#  DecisionTreeClassifier(max_features='sqrt', random_state=743781266),
#  DecisionTreeClassifier(max_features='sqrt', random_state=1899104372)]
